# %%
# import pandas as pd
import tweepy
from dotenv import load_dotenv
import os

load_dotenv()
# Out:
# True

# %%
my_key = os.getenv('API_KEY')
my_secret = os.getenv('API_KEY_SECRET')
access_token = os.getenv('ACCESS_TOKEN')
access_token_secret = os.getenv('ACCESS_TOKEN_SECRET')

# %%
auth = tweepy.OAuth1UserHandler(my_key, my_secret, access_token, access_token_secret)

api = tweepy.API(auth)

# %%
public_tweets = api.home_timeline()
first_3 = public_tweets[:3]

# %%
for tweet in first_3:
    print(tweet.text)
# Out:
# Boris Johnson fighting for political future after series of Tory resignations – UK politics live https://t.co/1C6TpNeU1T
# A cosmic storm in A.D. 993 released a pulse of radiation so powerful that it was recorded in the rings of the world… https://t.co/IFQbeVsa15
# Smuggling operation sent thousands of people across Channel illegally in small boats https://t.co/68DbC5R7Dk
